# %%
# importing the required library
import azure.cognitiveservices.speech as speechsdk
from azure.cognitiveservices.speech import SpeechConfig, SpeechRecognizer, AudioConfig

# %%
import os
os.getcwd()
import time

# %%
result1 = []
def speech_recognize_continuous_from_file():
    """performs continuous speech recognition with input from an audio file"""
    # provided azure subscription key  & end point as region
    speech_config = speechsdk.SpeechConfig(subscription='3d5bd686e1e94fb9b91dce5a665b32e0', region='eastus')
    # filename = 'the audio file should be in wav form'
    audio_config = speechsdk.audio.AudioConfig(filename='SIACArbitration.wav')
    
 
    speech_recognizer = speechsdk.SpeechRecognizer(speech_config=speech_config, audio_config=audio_config)
 
    done = False
 
    def stop_cb(evt):
        """callback that stops continuous recognition upon receiving an event `evt`"""
        print('CLOSING on {}'.format(evt))
        speech_recognizer.stop_continuous_recognition()
        nonlocal done
        done = True
 
    # Connect callbacks to the events fired by the speech recognizer
    speech_recognizer.recognizing.connect(lambda evt: print('RECOGNIZING: {}'.format(evt)))
    speech_recognizer.recognized.connect(lambda evt: result1.append(evt.result.text))
    speech_recognizer.session_started.connect(lambda evt: print('SESSION STARTED: {}'.format(evt)))
    speech_recognizer.session_stopped.connect(lambda evt: print('SESSION STOPPED {}'.format(evt)))
    speech_recognizer.canceled.connect(lambda evt: print('CANCELED {}'.format(evt)))
    # stop continuous recognition on either session stopped or canceled events
    speech_recognizer.session_stopped.connect(stop_cb)
    speech_recognizer.canceled.connect(stop_cb)
    # Start continuous speech recognition
    speech_recognizer.start_continuous_recognition()
    while not done:
        time.sleep(.5)
speech_recognize_continuous_from_file()
# Out:
# SESSION STARTED: SessionEventArgs(session_id=ab5c02504d4347938f541ae8e147a4b2)
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=ab5c02504d4347938f541ae8e147a4b2, result=SpeechRecognitionResult(result_id=1cd4fbbc57ce4f68967b025e16feb2fd, text="the", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=ab5c02504d4347938f541ae8e147a4b2, result=SpeechRecognitionResult(result_id=f544facde50e48f7b2686082d29e3b86, text="the first", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=ab5c02504d4347938f541ae8e147a4b2, result=SpeechRecognitionResult(result_id=d14da9081e1d479f8eb71d7f77defa68, text="the first hearing", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=ab5c02504d4347938f541ae8e147a4b2, result=SpeechRecognitionResult(result_id=2e1d3edf49e24e418278b77be6c77430, text="the first hearing scheduled", reason=ResultReason.RecognizingSpeech))
# ...

# %%
result1
# Out:
# ['The first hearing scheduled by the Tribunal is a brief one day hearing to decide the issue of jurisdiction. It is granted respondents council 3 hours in the morning and claimants council 3 hours after lunch to make their respective arguments. Thereafter, the arbitrators will have about 2 hours for their own internal deliberations.',
#  "The hearing takes place at Maxwell Chambers, Singapore's Premier arbitration facility.",
#  "Let's join them there to get a taste of this stage of the process, and perhaps some of the famous coffee there.",
#  'Presiding arbitrator Sir. Members of the tribunal are very good morning. We represent the respondent Electro ACE Incorporated in this arbitration and we will address you this morning on the issue of jurisdiction.',
#  'The respondent challenges the jurisdiction of this honorable tribunal to decide this dispute on the ground that the contract between the parties is tainted by illegality.',
# ...
